# %% [markdown]
# # 数据下载创建

# %%
import requests
import json
import gzip
import shutil
import time
import os
from io import BytesIO
import pprint

# %%
S3_BUCKET_URL = "https://vcthackathon-data.s3.us-west-2.amazonaws.com"

# (game-changers, vct-international, vct-challengers)
LEAGUE = "game-changers"

# (2022, 2023, 2024)
YEAR = 2022

def download_gzip_and_write_to_json(file_name):
    if os.path.isfile(f"{file_name}.json"):
        return False

    remote_file = f"{S3_BUCKET_URL}/{file_name}.json.gz"
    response = requests.get(remote_file, stream=True)

    if response.status_code == 200:
        gzip_bytes = BytesIO(response.content)
        with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
            with open(f"{file_name}.json", 'wb') as output_file:
                shutil.copyfileobj(gzipped_file, output_file)
            print(f"{file_name}.json written")
        return True
    elif response.status_code == 404:
        # Ignore
        return False
    else:
        print(response)
        print(f"Failed to download {file_name}")
        return False


def download_esports_files(LEAGUE, YEAR):
    directory = f"{LEAGUE}/esports-data"

    if not os.path.exists(directory):
        os.makedirs(directory)

    esports_data_files = ["leagues", "tournaments", "players", "teams", "mapping_data"]
    for file_name in esports_data_files:
        download_gzip_and_write_to_json(f"{directory}/{file_name}")


def download_games(LEAGUE, YEAR):
    start_time = time.time()

    local_mapping_file = f"{LEAGUE}/esports-data/mapping_data.json"
    with open(local_mapping_file, "r") as json_file:
        mappings_data = json.load(json_file)

    local_directory = f"{LEAGUE}/games/{YEAR}"
    if not os.path.exists(local_directory):
        os.makedirs(local_directory)

    game_counter = 0

    for esports_game in mappings_data:
        s3_game_file = f"{LEAGUE}/games/{YEAR}/{esports_game['platformGameId']}"
        
        response = download_gzip_and_write_to_json(s3_game_file)
        
        if (response == True):
            game_counter += 1
            if game_counter % 10 == 0:
                print(f"----- 已处理 {game_counter} 场比赛，当前运行时间: {round((time.time() - start_time)/60, 2)} 分钟")


if __name__ == "__main__":
    leagues = ["game-changers", "vct-international", "vct-challengers"]
    years = [2022, 2023, 2024]
    
    for league in leagues:
        for year in years:
            print(f"正在下载 {league} {year} 的数据...")
            # 先下载基本数据关于选手，队伍...
            download_esports_files(league, year)
            # download_games(league, year)

    # download_esports_files("game-changers", 2022)
    # download_games("game-changers", 2022)

    print("所有数据下载完成")
# Out:
# 正在下载 game-changers 2022 的数据...
# 正在下载 game-changers 2023 的数据...
# 正在下载 game-changers 2024 的数据...
# 正在下载 vct-international 2022 的数据...
# vct-international/esports-data/mapping_data.json written
# 正在下载 vct-international 2023 的数据...
# 正在下载 vct-international 2024 的数据...
# 正在下载 vct-challengers 2022 的数据...
# vct-challengers/esports-data/leagues.json written
# vct-challengers/esports-data/tournaments.json written
# vct-challengers/esports-data/players.json written
# vct-challengers/esports-data/teams.json written
# vct-challengers/esports-data/mapping_data.json written
# 正在下载 vct-challengers 2023 的数据...
# 正在下载 vct-challengers 2024 的数据...
# 所有数据下载完成

# %%
import gzip
import json

total_players = {}

def extract_players(file_path, players):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        
    for player in data:
        player_id = player['id']
        
        handle = player['handle']
        name = f"{player['first_name']} {player['last_name']}"
        team = player['home_team_id']
        
        if player_id not in players:
            players[player_id] = {
                'handle': handle,
                'name': name,
                'teams': team,
            }
        else:
            # 处理handle
            if players[player_id]['handle'] != handle:
                if isinstance(players[player_id]['handle'], list):
                    if handle not in players[player_id]['handle']:
                        players[player_id]['handle'].append(handle)
                else:
                    players[player_id]['handle'] = [players[player_id]['handle'], handle]
            
            # 处理name
            if players[player_id]['name'] != name:
                if isinstance(players[player_id]['name'], list):
                    if name not in players[player_id]['name']:
                        players[player_id]['name'].append(name)
                else:
                    players[player_id]['name'] = [players[player_id]['name'], name]
            
            # 处理teams
            if players[player_id]['teams'] != team:
                if isinstance(players[player_id]['teams'], list):
                    if team not in players[player_id]['teams']:
                        players[player_id]['teams'].append(team)
                else:
                    players[player_id]['teams'] = [players[player_id]['teams'], team]

    return players

file_paths = [
    "game-changers/esports-data/players.json",
    "vct-challengers/esports-data/players.json",
    "vct-international/esports-data/players.json"
]

extract_players(file_paths[0], total_players)
extract_players(file_paths[1], total_players)
extract_players(file_paths[2], total_players)
print(f"所有联赛的选手总数: {len(total_players)}")


file_path = 'all_players.json'
with open(file_path, 'w', encoding='utf-8') as file:
    json.dump(total_players, file, ensure_ascii=False, indent=4)

print(f"所有选手已写入 {file_path}")
# Out:
# 所有联赛的选手总数: 4549
# 所有选手已写入 all_players.json

# %% [markdown]
# ## Auxiliary functions

# %%
# 读取 all_players.json
def load_players(file_path='all_players.json'):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)


# 遍历每个game，添加player的information
def add_player_property(players, data, league, year, mapping_data, property, calculate_function):

    result = calculate_function(league, year, data, mapping_data)

    for id, info in result.items():

        players[id][property] = info

        print(f"id: {id} added info")
        pprint.pprint(info)


# 保存选手数据
def save_players(players, file_path='all_players.json'):
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(players, file, ensure_ascii=False, indent=4)
    print(f"所有选手数据已更新并保存到 {file_path}")


def get_game_files(root_dir='.'):
    game_files = []
    target_folders = ['game-changers/games/2022/', 'vct-challengers/games/2022/']
    
    for folder in target_folders:
        folder_path = os.path.join(root_dir, folder)
        if os.path.exists(folder_path):
            for root, dirs, files in os.walk(folder_path):
                for file in files:
                    if file.endswith('.json'):
                        game_files.append(os.path.join(root, file))
    
    print(f"找到 {len(game_files)} 个文件")
    return game_files

# 测试函数
game_files = get_game_files()
print("前5个文件路径:")
for file in game_files[:5]:
    print(file)


def extract_player_information(league, year, data, mapping_data):

    result = {}

    # 从data中找出包含'configuration'键的元素
    configuration_element = next((element for element in data if isinstance(element, dict) and 'configuration' in element), None)

    if configuration_element:
        if 'configuration' in configuration_element and 'players' in configuration_element['configuration']:
            players = configuration_element['configuration']['players']
            for player in players:
                if 'selectedAgent' in player:

                    player_id = map_player_id(configuration_element['platformGameId'], player['playerId']['value'], mapping_data)

                    result[player_id] = {
                        'league': league,
                        'year': year,
                        'gameId': configuration_element['platformGameId'],
                        'agent': player['selectedAgent']
                    }
        else:
            print("在configuration中没有找到'players'键")
    else:
        print("没有找到包含 'configuration' 键的元素")

    return result  


def map_player_id(platform_game_id, player_id, mappings):
    # Find the mapping for the platformGameId
    for mapping in mappings:
        if mapping['platformGameId'] == platform_game_id:
            # Return the corresponding esports player ID from participantMapping
            return mapping['participantMapping'].get(str(player_id), player_id)  # Return player_id if not found
    return player_id  # Return the original player_id if platformGameId is not found

# test
with open('game-changers/games/2022/val:4b417603-e12d-4382-8e8d-5bb2f20ef9e0.json', 'r') as file:   
    data = json.load(file)

with open('game-changers/esports-data/mapping_data.json', 'r') as file:   
    mapping_data = json.load(file)

result = extract_player_information('game-changers', 2022, data, mapping_data)
print("\n玩家选择的英雄信息：")
pprint.pprint(result)
# Out:
# 找到 3 个文件
# 前5个文件路径:
# ./game-changers/games/2022/val:5f5fbb51-f655-4bf3-9bcb-896051dc69d6.json
# ./game-changers/games/2022/val:4f3778a8-1bb9-43d5-bf49-a8042e7d0a5f.json
# ./game-changers/games/2022/val:4b417603-e12d-4382-8e8d-5bb2f20ef9e0.json
#
# 玩家选择的英雄信息：
# {'106371733375991351': {'agent': {'fallback': {'displayName': '',
#                                                'guid': '707EAB51-4836-F488-046A-CDA6BF494859'},
#                                   'type': 'UNKNOWN'},
#                         'gameId': 'val:4b417603-e12d-4382-8e8d-5bb2f20ef9e0',
#                         'league': 'game-changers',
#                         'year': 2022},
#  '106371734777609853': {'agent': {'fallback': {'displayName': '',
#                                                'guid': '569FDD95-4D10-43AB-CA70-79BECC718B46'},
#                                   'type': 'UNKNOWN'},
#                         'gameId': 'val:4b417603-e12d-4382-8e8d-5bb2f20ef9e0',
# ...

# %% [markdown]
# # Main
# 每个选手使用的英雄

# %%
import os
import json

def process_games(all_players, root_dir='..'):
    game_files = get_game_files()
    
    for game_file in game_files:
        with open(game_file, 'r') as file:
            game_data = json.load(file)
        
        # 加载映射数据
        mapping_file_path = os.path.join(os.path.dirname(game_file), '../../esports-data/mapping_data.json')
        
        with open(mapping_file_path, 'r', encoding='utf-8') as mapping_file:
            mapping_data = json.load(mapping_file)

        # 从game_file路径中提取league和year
        path_parts = game_file.split(os.sep)
        year = path_parts[-2]
        league = path_parts[-4]  # 获取正确的league值
        print(f"league: {league}, year: {year}")
        
        add_player_property(all_players, game_data, league, year, mapping_data, 'hero', extract_player_information)
        # TODO add more property
        # add_player_property(all_players, game_data, league, year, mapping_data, 'damage', x x x x x)


# 主函数
def main():
    all_players = load_players()
    
    # 处理所有游戏
    process_games(all_players)

    # save_players(all_players)

if __name__ == "__main__":
    main()
# Out:
# 找到 3 个文件
# league: game-changers, year: 2022
# id: 106371733375991351 added info
# {'agent': {'fallback': {'displayName': '',
#                         'guid': '707EAB51-4836-F488-046A-CDA6BF494859'},
#            'type': 'UNKNOWN'},
#  'gameId': 'val:5f5fbb51-f655-4bf3-9bcb-896051dc69d6',
#  'league': 'game-changers',
#  'year': '2022'}
# id: 106371738216349245 added info
# {'agent': {'fallback': {'displayName': '',
#                         'guid': 'F94C3B30-42BE-E959-889C-5AA313DBA261'},
#            'type': 'UNKNOWN'},
#  'gameId': 'val:5f5fbb51-f655-4bf3-9bcb-896051dc69d6',
#  'league': 'game-changers',
#  'year': '2022'}
# id: 106371739789225404 added info
# {'agent': {'fallback': {'displayName': '',
#                         'guid': 'DADE69B4-4F5A-8528-247B-219E5A1FACD6'},
#            'type': 'UNKNOWN'},
#  'gameId': 'val:5f5fbb51-f655-4bf3-9bcb-896051dc69d6',
#  'league': 'game-changers',
#  'year': '2022'}
# id: 106371736320404919 added info
# ...

# %% [markdown]
# # Game log analyse

# %%
# val:4b417603-e12d-4382-8e8d-5bb2f20ef9e0
# val:4f3778a8-1bb9-43d5-bf49-a8042e7d0a5f
# val:5f5fbb51-f655-4bf3-9bcb-896051dc69d6
with open('game-changers/games/2022/val:4b417603-e12d-4382-8e8d-5bb2f20ef9e0.json', 'r') as file:   
    data = json.load(file)

print(len(data))
# Out:
# 6674

# %%
# 初始化一个字典来存储所有键及其出现次数
键计数 = {}

# 遍历data中的每个元素
for 元素 in data:
    # 如果元素是字典，则统计其键的出现次数
    if isinstance(元素, dict):
        for 键 in 元素.keys():
            键计数[键] = 键计数.get(键, 0) + 1

# 打印所有键及其出现次数
print("data中所有键及其出现次数：")
for 键, 次数 in sorted(键计数.items(), key=lambda x: x[1], reverse=True):
    print(f"{键}: {次数}")

print(f"\n总共有 {len(键计数)} 个唯一的键")
# Out:
# data中所有键及其出现次数：
# platformGameId: 6674
# metadata: 6674
# snapshot: 2515
# observerTarget: 2078
# inventoryTransaction: 675
# damageEvent: 550
# configuration: 252
# playerSpawn: 185
# playerDied: 140
# spikeStatus: 122
# gamePhase: 74
# roundStarted: 18
# roundDecided: 18
# roundCeremony: 18
# roundEnded: 17
# playerRevived: 5
# playerDowned: 4
# playerRecovered: 2
# gameDecided: 1
#
# 总共有 19 个唯一的键

# %%
# 初始化一个列表来存储每个元素的键
所有键列表 = []

# 遍历data中的每个元素
for 索引, 元素 in enumerate(data):
    # 如果元素是字典，则获取其键
    if isinstance(元素, dict):
        键 = list(元素.keys())
        所有键列表.append(键)
        print(f"元素 {索引} 的键: {键}")
    else:
        print(f"元素 {索引} 不是字典")

print(f"\n总共有 {len(所有键列表)} 个元素")
print(f"不同的键集合数量: {len(set(tuple(键) for 键 in 所有键列表))}")
# Out:
# 元素 0 的键: ['platformGameId', 'snapshot', 'metadata']
# 元素 1 的键: ['platformGameId', 'configuration', 'metadata']
# 元素 2 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 3 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 4 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 5 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 6 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 7 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 8 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 9 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 10 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 11 的键: ['platformGameId', 'observerTarget', 'metadata']
# 元素 12 的键: ['platformGameId', 'metadata', 'snapshot']
# 元素 13 的键: ['platformGameId', 'metadata', 'snapshot']
# 元素 14 的键: ['platformGameId', 'metadata', 'snapshot']
# 元素 15 的键: ['platformGameId', 'metadata', 'snapshot']
# 元素 16 的键: ['platformGameId', 'snapshot', 'metadata']
# ...

# %%
# 查找包含 'gameDecided' 键的元素
游戏决定元素 = [元素 for 元素 in data if isinstance(元素, dict) and 'gameDecided' in 元素]

print(f"找到 {len(游戏决定元素)} 个包含 'gameDecided' 键的元素")

if 游戏决定元素:
    print("\n第一个包含 'gameDecided' 的元素：")
    pprint.pprint(游戏决定元素[0])
else:
    print("没有找到包含 'gameDecided' 键的元素")
# Out:
# 找到 1 个包含 'gameDecided' 键的元素
#
# 第一个包含 'gameDecided' 的元素：
# {'gameDecided': {'spikeMode': {'attackingTeam': {'value': 15},
#                                'completedRounds': [{'roundNumber': 1,
#                                                     'spikeModeResult': {'attackingTeam': {'value': 14},
#                                                                         'cause': 'ELIMINATION',
#                                                                         'defendingTeam': {'value': 15}},
#                                                     'winningTeam': {'value': 14}},
#                                                    {'roundNumber': 2,
#                                                     'spikeModeResult': {'attackingTeam': {'value': 14},
#                                                                         'cause': 'DETONATE',
#                                                                         'defendingTeam': {'value': 15}},
# ...

# %% [markdown]
# 在《VALORANT》中，玩家在比赛过程中不能随意更换特工。每位玩家在比赛开始前需要从可用的特工中选择一个，并在整个比赛中保持该特工，直到比赛结束。
#
# 只需要read一条**configuration**的json就可以得到player的信息就是英雄。

# %%
def extract_player_information(league, year, game_json, mapping_data):

    result = {}

    # 从data中找出包含'configuration'键的元素
    configuration_element = next((element for element in data if isinstance(element, dict) and 'configuration' in element), None)

    if configuration_element:
        if 'configuration' in configuration_element and 'players' in configuration_element['configuration']:
            players = configuration_element['configuration']['players']
            print("\n玩家选择的英雄信息：")
            for player in players:
                if 'selectedAgent' in player:
                    print(f"玩家ID: {player.get('playerId', {}).get('value', '未知')}, 选择的英雄: {player['selectedAgent']}")

                    player_id = map_player_id(configuration_element['platformGameId'], player['playerId']['value'], mapping_data)
                    result[player_id] = {
                        'league': league,
                        'year': year,
                        'gameId': configuration_element['platformGameId'],
                        'agent': player['selectedAgent']
                    }
        else:
            print("在configuration中没有找到'players'键")
    else:
        print("没有找到包含 'configuration' 键的元素")

    return result  


def map_player_id(platform_game_id, player_id, mappings):
    # Find the mapping for the platformGameId
    for mapping in mappings:
        if mapping['platformGameId'] == platform_game_id:
            # Return the corresponding esports player ID from participantMapping
            return mapping['participantMapping'].get(str(player_id), player_id)  # Return player_id if not found
    return player_id  # Return the original player_id if platformGameId is not found

# test
with open('game-changers/games/2022/val:4b417603-e12d-4382-8e8d-5bb2f20ef9e0.json', 'r') as file:   
    data = json.load(file)

with open('game-changers/esports-data/mapping_data.json', 'r') as file:   
    mapping_data = json.load(file)

result = extract_player_information('game-changers', 2022, data, mapping_data)
pprint.pprint(result)
# Out:
# 玩家选择的英雄信息：
# 玩家ID: 1, 选择的英雄: {'fallback': {'guid': '601DBBE7-43CE-BE57-2A40-4ABD24953621', 'displayName': ''}, 'type': 'UNKNOWN'}
# 玩家ID: 2, 选择的英雄: {'fallback': {'guid': '569FDD95-4D10-43AB-CA70-79BECC718B46', 'displayName': ''}, 'type': 'UNKNOWN'}
# 玩家ID: 3, 选择的英雄: {'fallback': {'guid': '320B2A48-4D9B-A075-30F1-1F93A9B638FA', 'displayName': ''}, 'type': 'UNKNOWN'}
# 玩家ID: 4, 选择的英雄: {'fallback': {'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'displayName': ''}, 'type': 'UNKNOWN'}
# 玩家ID: 5, 选择的英雄: {'fallback': {'guid': '22697A3D-45BF-8DD7-4FEC-84A9E28C69D7', 'displayName': ''}, 'type': 'UNKNOWN'}
# 玩家ID: 6, 选择的英雄: {'fallback': {'guid': '707EAB51-4836-F488-046A-CDA6BF494859', 'displayName': ''}, 'type': 'UNKNOWN'}
# 玩家ID: 7, 选择的英雄: {'fallback': {'guid': '601DBBE7-43CE-BE57-2A40-4ABD24953621', 'displayName': ''}, 'type': 'UNKNOWN'}
# 玩家ID: 8, 选择的英雄: {'fallback': {'guid': '320B2A48-4D9B-A075-30F1-1F93A9B638FA', 'displayName': ''}, 'type': 'UNKNOWN'}
# ...
